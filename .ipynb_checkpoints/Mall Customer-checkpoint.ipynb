# %% [markdown]
# ## Performing K-Means clustering to segregate customers based on the data in form of optimal clusters.
#
# Process:
# 1. Understanding the data
# 2. Perform Elbow method to find Optimal No. of clusters.
# 3. Training a model using unsupervised learning algorithm(K-Means)
# 4. Plotting the clusters

# %%
# import all necessary libraries
import numpy as np
import pandas as pd

# for visuals
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# ggplot style sheet
plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
# Read file
df = pd.read_csv(r"C:\Users\Andy Joseph\Desktop\Projects\Mall Customers_K means\Mall_Customers.csv")
df.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
# Shape
df.shape
# Out:
# (200, 5)

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# Handling missing values
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# ### Feature Selection

# %%
X = df.iloc[:, [3,4]].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %% [markdown]
# ### Standardization
# Standardizing data features before clustering helps in achieving more meaningful and robust clusters by ensuring that all features are treated equally and preventing biases that may arise due to differences in feature scales.

# %%
# Standardize the features
from sklearn.preprocessing import StandardScaler

# Instantiate the StandardScaler
scaler = StandardScaler()

# Scale the feature matrix
X_scaled = scaler.fit_transform(X)

# Display the scaled features
X_scaled
# Out:
# array([[-1.73899919, -0.43480148],
#        [-1.73899919,  1.19570407],
#        [-1.70082976, -1.71591298],
#        [-1.70082976,  1.04041783],
#        [-1.66266033, -0.39597992],
#        [-1.66266033,  1.00159627],
#        [-1.62449091, -1.71591298],
#        [-1.62449091,  1.70038436],
#        [-1.58632148, -1.83237767],
#        [-1.58632148,  0.84631002],
#        [-1.58632148, -1.4053405 ],
#        [-1.58632148,  1.89449216],
#        [-1.54815205, -1.36651894],
#        [-1.54815205,  1.04041783],
#        [-1.54815205, -1.44416206],
#        [-1.54815205,  1.11806095],
#        [-1.50998262, -0.59008772],
#        [-1.50998262,  0.61338066],
#        [-1.43364376, -0.82301709],
#        [-1.43364376,  1.8556706 ],
#        [-1.39547433, -0.59008772],
#        [-1.39547433,  0.88513158],
#        [-1.3573049 , -1.75473454],
#        [-1.3573049 ,  0.88513158],
#        [-1.24279661, -1.4053405 ],
#        [-1.24279661,  1.23452563],
#        [-1.24279661, -0.7065524 ],
# ...

# %% [markdown]
# ### Performing Elbow Method To Find Optimal No. of Clusters
# - Using K-Means to iterate from 1 to 11 clusters and plotting a Elbow plot.
# - Deciding optimal number of clusters to be used.
#
# The Elbow method is a heuristic used to determine the optimal number of clusters in a dataset for K-Means clustering. It involves plotting the within-cluster sum of squares (WCSS) against the number of clusters, and then identifying the "elbow" point in the plot. The elbow point is the point at which the rate of decrease in WCSS sharply changes, forming an "elbow" shape in the plot. This point is considered to be a good estimate of the optimal number of clusters, as it represents the point where the addition of more clusters does not lead to a significant improvement in the model's performance.

# %%
from sklearn.cluster import KMeans
wcss = []

# %% [markdown]
# WCSS stands for "Within-Cluster Sum of Squares." In clustering, WCSS is a measure that calculates the sum of the squared distances between each data point within a cluster and the centroid of that cluster.

# %% [markdown]
# The centroid serves as the "center" of the cluster and is used in algorithms such as K-Means clustering to assign data points to their nearest centroid, thereby forming clusters.

# %%
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('The elbow method')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS Values')
plt.show()

# %% [markdown]
# ### Training a Model Using Unsupervised Learning Algorithm(K-Means)
#
# - Initializing our K-Means Model with selected optimal No.of clusters.
# - Plot of clusters, and gain intuitions regarding our customers.

# %%
kmeansmodel = KMeans(n_clusters = 5, init='k-means++', random_state = 0)

# %%
y_kmeans = kmeansmodel.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s=80, c='red', label='Customer 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s=80, c='blue', label='Customer 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s=80, c='yellow', label='Customer 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s=80, c='black', label='Customer 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s=80, c='green', label='Customer 5')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='magenta', label='Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
# The insights derived from the chart indicate the following:
#
# - Customer 4 (Black) has an annual income of 20-40k dollars but spends more than their annual income based on their high spending score.
#
# - Customer 1 (Red) has a high annual income of about 70-140k dollars but spends less than 40k dollars, indicating that they are conservative in their spending habits.
#
# - Customer 2 (Blue) has an annual income between 40-80k dollars and spends within that range, specifically between 40-60k dollars. This group appears to balance their annual income and spending score effectively.
#
# Businesses may find Customer 2 (Blue) particularly attractive for targeting as they demonstrate a balanced approach to spending relative to their income.
